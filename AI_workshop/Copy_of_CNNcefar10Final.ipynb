# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Load the dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Show the first 10 sample images
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train[i])
    plt.title(y_train[i])
    plt.axis('off')
plt.show()

# Define the model
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 18s 0us/step
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Epoch 1/10
# 1563/1563 [==============================] - 14s 4ms/step - loss: 1.5634 - accuracy: 0.4256
# Epoch 2/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1832 - accuracy: 0.5785
# Epoch 3/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.0368 - accuracy: 0.6351
# Epoch 4/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9465 - accuracy: 0.6679
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8801 - accuracy: 0.6948
# Epoch 6/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8231 - accuracy: 0.7117
# Epoch 7/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7844 - accuracy: 0.7282
# Epoch 8/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7400 - accuracy: 0.7433
# Epoch 9/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7083 - accuracy: 0.7522
# Epoch 10/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6737 - accuracy: 0.7642
# 313/313 - 1s - loss: 0.8666 - accuracy: 0.7033 - 1s/epoch - 4ms/step
#
# Test accuracy: 0.7032999992370605

# %%
plt.imshow(x_train[7])

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
y_pred = model.predict(x_test)
y_pred_classes = [np.argmax(element) for element in y_pred]
print('Classification Report:  \n',   classification_report(y_test, y_pred_classes))
# Out:
# 313/313 [==============================] - 1s 4ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76      1000
#            1       0.80      0.83      0.82      1000
#            2       0.77      0.47      0.58      1000
#            3       0.52      0.54      0.53      1000
#            4       0.66      0.67      0.67      1000
#            5       0.57      0.68      0.62      1000
#            6       0.77      0.79      0.78      1000
#            7       0.79      0.72      0.75      1000
#            8       0.81      0.82      0.81      1000
#            9       0.70      0.87      0.78      1000
#
#     accuracy                           0.71     10000
#    macro avg       0.72      0.71      0.71     10000
# weighted avg       0.72      0.71      0.71     10000

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest_loss:', test_loss)
print('\nTest accuracy:', test_acc)

# %%
y_pred = model.predict(x_test)
y_pred[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e3a2e3cef772> in <module>
# ----> 1 y_pred = model.predict(x_test)
#       2 y_pred[:5]
#
# NameError: name 'model' is not defined

# %%
y_classes = [np.argmax(element) for element in y_pred]
y_classes[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b1f464f14bd1> in <module>
# ----> 1 y_classes = [np.argmax(element) for element in y_pred]
#       2 y_classes[:5]
#
# NameError: name 'y_pred' is not defined

# %%
y_test[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fab7fc047dee> in <module>
# ----> 1 y_test[:5]
#
# NameError: name 'y_test' is not defined

# %%
y_test = y_test.reshape(-1,)
y_test[:5]
# Out:
# array([3, 8, 8, 0, 6], dtype=uint8)

# %%
classes = ['Aeroplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'ship', 'Truck']

# %%
classes
# Out:
# ['Aeroplane',
#  'Automobile',
#  'Bird',
#  'Cat',
#  'Deer',
#  'Dog',
#  'Frog',
#  'Horse',
#  'ship',
#  'Truck']

# %%
def plot_sample(X, y, index):
    plt.figure(figsize=(15,2))
    plt.imshow(X[index])
    plt.xlabel(classes[y[index]])

# %%
plot_sample(x_test, y_test, 4)

# %%
plot_sample(x_test, y_test, 100)

# %%
classes[y_classes[60]]
# Out:
# 'Horse'

# %%
classes[y_classes[100]]
# Out:
# 'Horse'

# %%
plt.imshow(x_train[4])

# %%
plt.imshow(x_train[1])

# %%
y_train[1]
# Out:
# array([9], dtype=uint8)

# %%
a=1

# %%
a
# Out:
# 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Load the dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize the data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Show the first 10 sample images
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train[i])
    plt.title(y_train[i])
    plt.axis('off')
plt.show()

# Define the model
model = keras.Sequential([
    keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(16, (3, 3), activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10)

# Predict the labels
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Epoch 1/10
# 1563/1563 [==============================] - 15s 4ms/step - loss: 1.5770 - accuracy: 0.4218
# Epoch 2/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2730 - accuracy: 0.5441
# Epoch 3/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1602 - accuracy: 0.5872
# Epoch 4/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0874 - accuracy: 0.6134
# Epoch 5/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0269 - accuracy: 0.6367
# Epoch 6/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9755 - accuracy: 0.6550
# Epoch 7/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9270 - accuracy: 0.6720
# Epoch 8/10
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8911 - accuracy: 0.6857
# Epoch 9/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8578 - accuracy: 0.6967
# Epoch 10/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8234 - accuracy: 0.7100
# 313/313 [==============================] - 1s 2ms/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
plt.imshow(x_train[1])

# %%
# Show the first 10 classified images
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_test[i])
    plt.title("True: " + str(y_test[i]) + "\nPred: " + str(y_pred[i]))
    plt.axis('off')
plt.show()

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.8788 - accuracy: 0.7080 - 786ms/epoch - 3ms/step
#
# Test accuracy: 0.7080000042915344

# %%
# Show all the images for the 10 class labels
class_labels = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
for i in range(10):
    class_index = np.where(y_test == i)
    for j in range(5):
        plt.subplot(10, 5, i*5+j+1)
        plt.imshow(x_test[class_index][j])
        plt.title(class_labels[i])
        plt.axis('off')
plt.show()
